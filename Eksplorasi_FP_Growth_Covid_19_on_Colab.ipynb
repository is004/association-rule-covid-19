# %% [markdown]
# # **Eksplorasi FP-Growth Dataset Covid-19 (mlxtend on Colab Notebook)**
# Eksplorasi sangat sederhana untuk mencoba mencari korelasi dari dataset Covid-19 menggunakan algoritma FP-Growth (Frequent Pattern Growth) pada Python library mlxtend. <br><br> Eksplorasi ini bertujuan untuk mengetahui korelasi antara faktor status dirawat di rumah sakit; dirawat di ICU; memiliki penyakit komorbid; faktor gender; dan status kematian. Eksperimen dilakukan 2 kali: Round #1 tanpa memasukkan komponen gender; Round #2 dengan memasukkan komponen gender. <br><br>
#
# Wawasan yang ingin digali antara lain adalah:
# *    Apakah riwayat penyakit komorbid berhubungan dengan status dirawat di ICU?
# *    Apakah gender berpengaruh pada tingkat kematian? <br><br>
#
# Sumber dataset: "Covid-19 Case Surveillance" (https://www.kaggle.com/arashnic/covid19-case-surveillance-public-use-dataset). Dataset ini berisi kumpulan data pasien individual terdeidentifikasi yang mencakup karakteristik demografis, riwayat paparan, indikator dan hasil keparahan penyakit, data klinis, hasil uji diagnostik laboratorium, dan komorbiditas. Overview isi dataset dapat dilihat di: https://github.com/is004/eksplorasi-dataset-covid-19/blob/main/Eksplorasi_Dataset_Covid-19_IS004_01A.ipynb <br><br> Tahapan langkah: <br>
#
# 1.   Hubungkan Google Colab dengan Google Drive, unzip dataset
# 2.   Install dan import library
# 3.   Load dataset ke dataframe <br><br>
# 4.   Preprocessing dan transformasi dataset (Round #1: tanpa "sex")
# 5.   Proses fpgrowth frequent itemsets
# 6.   Proses association rules
# 7.   Interpretasi hasil dan kesimpulan <br><br>
# 8.   Preprocessing dan transformasi dataset (Round #2: dengan "sex")
# 5.   Proses fpgrowth frequent itemsets
# 6.   Proses association rules
# 7.   Interpretasi hasil dan kesimpulan

# %% [markdown]
# # **PREPARASI**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzip file dataset:

# %%
# !unzip '/content/drive/MyDrive/DATASET1/Covid-19/Kaggle_Covid-19.zip'
# Out:
# Archive:  /content/drive/MyDrive/DATASET1/Covid-19/Kaggle_Covid-19.zip
#   inflating: COVID-19_Case_Surveillance_Public_Use_Data.csv

# %% [markdown]
# Install packages: <br> (required: mlxtend-0.21.0)

# %%
# !pip install mlxtend --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.8/dist-packages (0.14.0)
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from mlxtend) (57.4.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from mlxtend) (3.5.3)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.8/dist-packages (from mlxtend) (1.3.5)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.8/dist-packages (from mlxtend) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.24.2->mlxtend) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.15.0)
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed mlxtend-0.21.0

# %%
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth
import pandas as pd

# %% [markdown]
# Load dataframe dari dataset Covid-19:

# %%
data = pd.read_csv('COVID-19_Case_Surveillance_Public_Use_Data.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4  10 - 19 Years           Black, Non-Hispanic       No       No       No
#
#   medcond_yn
# 0         No
# 1         No
# 2         No
# 3    Missing
# 4        Yes

# %%
data.shape
# Out:
# (8405079, 11)

# %% [markdown]
# *****
# # **ROUND #1**

# %% [markdown]
# *****
# **PREPROCESSING**

# %% [markdown]
# Buat dataframe baru (data1) berisi hanya kolom yang ingin dieksplorasi: <br>
# (Pada eksperimen round #1 ini hanya dipilih kolom "hosp_yn", "icu_yn", "death_yn", "medcond_yn" -- tujuannya untuk mengetahui hubungan antara 4 status tersebut) <br><br> Arti status: hosp_yn adalah status dirawat di rumah sakit; icu_yn adalah status dirawat di ICU; death_yn adalah status meninggal; medcond_yn adalah status memiliki riwayat penyakit komorbid.

# %%
data1 = data[["hosp_yn", "icu_yn", "death_yn", "medcond_yn"]]
data1.head()
# Out:
#    hosp_yn   icu_yn death_yn medcond_yn
# 0       No  Unknown       No         No
# 1       No       No       No         No
# 2       No       No       No         No
# 3  Missing  Missing       No    Missing
# 4       No       No       No        Yes

# %% [markdown]
# Cek isi unik per kolom:

# %%
data1["hosp_yn"].unique()
# Out:
# array(['No', 'Missing', 'Unknown', 'Yes'], dtype=object)

# %%
data1["icu_yn"].unique()
# Out:
# array(['Unknown', 'No', 'Missing', 'Yes'], dtype=object)

# %%
data1["death_yn"].unique()
# Out:
# array(['No', 'Missing', 'Unknown', 'Yes'], dtype=object)

# %%
data1["medcond_yn"].unique()
# Out:
# array(['No', 'Missing', 'Yes', 'Unknown'], dtype=object)

# %% [markdown]
# Hapus baris berisi null, Missing, Unknown; simpan dalam data1_clean:

# %%
data1clean = data1.dropna()
data1clean = data1.loc[(data1['hosp_yn'] != 'Missing') & (data1['hosp_yn'] != 'Unknown') &
(data1['icu_yn'] != 'Missing') & (data1['icu_yn'] != 'Unknown') &
(data1['death_yn'] != 'Missing') & (data1['death_yn'] != 'Unknown') &
(data1['medcond_yn'] != 'Missing') & (data1['medcond_yn'] != 'Unknown')]

# %%
data1clean.head()
# Out:
#    hosp_yn icu_yn death_yn medcond_yn
# 1       No     No       No         No
# 2       No     No       No         No
# 4       No     No       No        Yes
# 11      No     No       No         No
# 14      No     No       No        Yes

# %%
data1clean.count()
# Out:
# hosp_yn       550507
# icu_yn        550507
# death_yn      550507
# medcond_yn    550507
# dtype: int64

# %% [markdown]
# Transformasi data agar sesuai dengan format data input fpgrowth mlextend: <br> (Ubah Yes-No menjadi boolean True-False)

# %%
data1clean = data1clean.replace({'Yes': True, 'No': False})

# %%
data1clean.head()
# Out:
#     hosp_yn  icu_yn  death_yn  medcond_yn
# 1     False   False     False       False
# 2     False   False     False       False
# 4     False   False     False        True
# 11    False   False     False       False
# 14    False   False     False        True

# %%
data1clean.dtypes
# Out:
# hosp_yn       bool
# icu_yn        bool
# death_yn      bool
# medcond_yn    bool
# dtype: object

# %% [markdown]
# *****
# **FP-GROWTH PROCESSING #1**

# %% [markdown]
# Proses FP-Growth frequent itemsets, simpan hasilnya sebagai dataframe data_freq: <br> (parameter min_support=0.03)

# %%
freqItemsets = fpgrowth(data1clean, min_support=0.03, use_colnames = True)

# %%
data_freq = pd.DataFrame(freqItemsets)

# %%
data_freq.sort_values(by=['support'], ascending=False)
# Out:
#      support                         itemsets
# 0   0.522860                     (medcond_yn)
# 1   0.170764                        (hosp_yn)
# 4   0.143593            (medcond_yn, hosp_yn)
# 2   0.059189                       (death_yn)
# 3   0.058108                         (icu_yn)
# 8   0.057229                (icu_yn, hosp_yn)
# 5   0.055258           (death_yn, medcond_yn)
# 9   0.051340             (icu_yn, medcond_yn)
# 6   0.050859              (death_yn, hosp_yn)
# 11  0.050762    (icu_yn, medcond_yn, hosp_yn)
# 7   0.047930  (death_yn, medcond_yn, hosp_yn)
# 10  0.032123               (death_yn, icu_yn)
# 12  0.032027      (death_yn, icu_yn, hosp_yn)

# %% [markdown]
# Proses FP-Growth association rule, simpan hasilnya sebagai dataframe data_assoc: <br> (parameter metric="lift"; min_threshold=1)

# %%
assocRules = association_rules(freqItemsets, metric="lift", min_threshold=1)

# %%
data_assoc = pd.DataFrame(assocRules)

# %%
data_assoc.sort_values(by=['lift'], ascending=False)
# Out:
#                antecedents             consequents  antecedent support  \
# 25     (death_yn, hosp_yn)                (icu_yn)            0.050859
# 28                (icu_yn)     (death_yn, hosp_yn)            0.058108
# 27              (death_yn)       (icu_yn, hosp_yn)            0.059189
# 26       (icu_yn, hosp_yn)              (death_yn)            0.057229
# 17                (icu_yn)              (death_yn)            0.058108
# 16              (death_yn)                (icu_yn)            0.059189
# 21                (icu_yn)   (medcond_yn, hosp_yn)            0.058108
# 20   (medcond_yn, hosp_yn)                (icu_yn)            0.143593
# 29               (hosp_yn)      (death_yn, icu_yn)            0.170764
# 24      (death_yn, icu_yn)               (hosp_yn)            0.032123
# 18    (icu_yn, medcond_yn)               (hosp_yn)            0.051340
# 23               (hosp_yn)    (icu_yn, medcond_yn)            0.170764
# 12                (icu_yn)               (hosp_yn)            0.058108
# 13               (hosp_yn)                (icu_yn)            0.170764
# 8    (medcond_yn, hosp_yn)              (death_yn)            0.143593
# 9               (death_yn)   (medcond_yn, hosp_yn)            0.059189
# 6   (death_yn, medcond_yn)               (hosp_yn)            0.055258
# 11               (hosp_yn)  (death_yn, medcond_yn)            0.170764
# 5                (hosp_yn)              (death_yn)            0.170764
# 4               (death_yn)               (hosp_yn)            0.059189
# 7      (death_yn, hosp_yn)            (medcond_yn)            0.050859
# 10            (medcond_yn)     (death_yn, hosp_yn)            0.522860
# 2               (death_yn)            (medcond_yn)            0.059189
# 3             (medcond_yn)              (death_yn)            0.522860
# 19       (icu_yn, hosp_yn)            (medcond_yn)            0.057229
# 22            (medcond_yn)       (icu_yn, hosp_yn)            0.522860
# 14                (icu_yn)            (medcond_yn)            0.058108
# 15            (medcond_yn)                (icu_yn)            0.522860
# 1                (hosp_yn)            (medcond_yn)            0.170764
# 0             (medcond_yn)               (hosp_yn)            0.522860
#
#     consequent support   support  confidence       lift  leverage  conviction
# 25            0.058108  0.032027    0.629724  10.837076  0.029072    2.543753
# 28            0.050859  0.032027    0.551158  10.837076  0.029072    2.114646
# 27            0.057229  0.032027    0.541094   9.454878  0.028640    2.054387
# 26            0.059189  0.032027    0.559625   9.454878  0.028640    2.136388
# 17            0.059189  0.032123    0.552815   9.339815  0.028684    2.103852
# 16            0.058108  0.032123    0.542720   9.339815  0.028684    2.059772
# 21            0.143593  0.050762    0.873582   6.083730  0.042418    6.774382
# 20            0.058108  0.050762    0.353515   6.083730  0.042418    1.456943
# 29            0.032123  0.032027    0.187550   5.838471  0.026541    1.191306
# 24            0.170764  0.032027    0.997003   5.838471  0.026541  276.683062
# 18            0.170764  0.050762    0.988749   5.790133  0.041995   73.700269
# 23            0.051340  0.050762    0.297265   5.790133  0.041995    1.349954
# 12            0.170764  0.057229    0.984870   5.767419  0.047306   54.806648
# 13            0.058108  0.057229    0.335135   5.767419  0.047306    1.416665
# 8             0.059189  0.047930    0.333793   5.639435  0.039431    1.412190
# 9             0.143593  0.047930    0.809784   5.639435  0.039431    4.502285
# 6             0.170764  0.047930    0.867390   5.079454  0.038494    6.253185
# 11            0.055258  0.047930    0.280681   5.079454  0.038494    1.313384
# 5             0.059189  0.050859    0.297829   5.031822  0.040751    1.339860
# 4             0.170764  0.050859    0.859256   5.031822  0.040751    5.891804
# 7             0.522860  0.047930    0.942424   1.802442  0.021338    8.287202
# 10            0.050859  0.047930    0.091670   1.802442  0.021338    1.044930
# 2             0.522860  0.055258    0.933587   1.785540  0.024311    7.184443
# 3             0.059189  0.055258    0.105684   1.785540  0.024311    1.051990
# 19            0.522860  0.050762    0.887002   1.696443  0.020840    4.222556
# 22            0.057229  0.050762    0.097086   1.696443  0.020840    1.044142
# 14            0.522860  0.051340    0.883522   1.689788  0.020957    4.096413
# 15            0.058108  0.051340    0.098191   1.689788  0.020957    1.044447
# 1             0.522860  0.143593    0.840884   1.608240  0.054307    2.998697
# 0             0.170764  0.143593    0.274630   1.608240  0.054307    1.143190

# %% [markdown]
# *****
# **INTERPRETASI SEDERHANA & KESIMPULAN EKSPERIMEN ROUND #1** <br><br>
#
#
# *   Beberapa itemsets (antecedents --> consequents) yang menghasilkan nilai confidence tertinggi (> 0.98) adalah: (death_yn, icu_yn) --> (hosp_yn); (icu_yn, medcond_yn) -->	(hosp_yn); (icu_yn) -->	(hosp_yn). Tingginya confidence pada itemsets ini menggambarkan bahwa orang-orang yang dirawat di rumah sakit kemungkinan besar adalah orang-orang yang dirawat di ICU dan memiliki riwayat penyakit komorbid.
# *   Pada itemsets 13 (hosp_yn) -->	(icu_yn), nilai confidence cukup rendah (0.335). Asosiasi ini menggambarkan orang-orang yang dirawat di rumah sakit belum tentu dirawat di ICU.
# *   Hasil menarik terdapat pada 6 itemsets teratas, dengan nilai lift > 9.33. Tiga dari 6 itemsets ini memiliki item consequents (death_yn) dengan antecedents mengandung (icu_yn). Asosiasi ini menggambarkan tingginya tingkat kematian orang-orang yang dirawat di ICU.
# *   Asosiasi tersebut didukung dengan itemsets 20 (medcond_yn, hosp_yn) -->	(icu_yn) dengan nilai lift cukup tinggi 6.08, yang menggambarkan bahwa orang-orang yang dirawat di ICU kemungkinan besar memiliki riwayat penyakit komorbid.

# %% [markdown]
# *****
# # **ROUND #2**

# %% [markdown]
# *****
# **PREPROCESSING**

# %% [markdown]
# Buat dataframe baru (data2) berisi 5 kolom: <br>
# ("hosp_yn", "icu_yn", "death_yn", "medcond_yn", "sex" )

# %%
data2 = data[["hosp_yn", "icu_yn", "death_yn", "medcond_yn", "sex"]]
data2.head()
# Out:
#    hosp_yn   icu_yn death_yn medcond_yn   sex
# 0       No  Unknown       No         No  Male
# 1       No       No       No         No  Male
# 2       No       No       No         No  Male
# 3  Missing  Missing       No    Missing  Male
# 4       No       No       No        Yes  Male

# %% [markdown]
# Cek isi unik kolom "sex": <br>
# (isi unik kolom lainnya sudah dicek di eksperimen round 1)

# %%
data2["sex"].unique()
# Out:
# array(['Male', 'Unknown', 'Missing', 'Female', 'Other', nan], dtype=object)

# %% [markdown]
# Hapus baris berisi null; ambil baris berisi Yes, No, Male, Female; simpan dalam data2_clean: <br>
# (data pada kolom "sex" hanya dipakai yang berisi Male dan Female saja; data pada kolom lainnya hanya dipakai yang berisi Yes dan No saja)

# %%
data2clean = data2.dropna()
data2clean = data2.loc[((data2['hosp_yn'] == 'Yes') | (data2['hosp_yn'] == 'No')) &
((data2['icu_yn'] == 'Yes') | (data2['icu_yn'] == 'No')) &
((data2['death_yn'] == 'Yes') | (data2['death_yn'] == 'No')) &
((data2['medcond_yn'] == 'Yes') | (data2['medcond_yn'] == 'No')) &
((data2['sex'] == 'Male') | (data2['sex'] == 'Female'))]

# %% [markdown]
# Verifikasi cek isi unik kolom "sex" pada data2clean:

# %%
data2clean['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data2clean.head()
# Out:
#    hosp_yn icu_yn death_yn medcond_yn   sex
# 1       No     No       No         No  Male
# 2       No     No       No         No  Male
# 4       No     No       No        Yes  Male
# 11      No     No       No         No  Male
# 14      No     No       No        Yes  Male

# %%
data2clean.count()
# Out:
# hosp_yn       548892
# icu_yn        548892
# death_yn      548892
# medcond_yn    548892
# sex           548892
# dtype: int64

# %% [markdown]
# Transformasi data agar sesuai dengan format data input fpgrowth mlextend, simpan di data2transform:
# * Split kolom "sex" menjadi 2 kolom "male_yn" dan "female_yn": 1) Buat kolom baru "female_yn" berisi copy dari kolom "sex"; 2) Rename kolom "sex" menjadi "male_yn"
# * Ubah isi data pada kolom "male_yn": Male menjadi True, Female menjadi False; Ubah isi data pada kolom "female_yn": Male menjadi False; Female menjadi True
# * Ubah isi data Yes-No pada kolom lainnya menjadi True-False

# %%
data2transform = data2clean.assign(female_yn=data2clean.sex)
data2transform = data2transform.rename(columns = {'sex':'male_yn'})

# %%
data2transform['male_yn'] = data2transform['male_yn'].replace(['Male', 'Female'], [True, False])
data2transform['female_yn'] = data2transform['female_yn'].replace(['Male', 'Female'], [False, True])
data2transform = data2transform.replace(['Yes', 'No'], [True, False])
data2transform = data2transform.replace({'True': True, 'False': False})
data2transform.head()
# Out:
#     hosp_yn  icu_yn  death_yn  medcond_yn  male_yn  female_yn
# 1     False   False     False       False     True      False
# 2     False   False     False       False     True      False
# 4     False   False     False        True     True      False
# 11    False   False     False       False     True      False
# 14    False   False     False        True     True      False

# %%
data2transform.dtypes
# Out:
# hosp_yn       bool
# icu_yn        bool
# death_yn      bool
# medcond_yn    bool
# male_yn       bool
# female_yn     bool
# dtype: object

# %% [markdown]
# *****
# **FP-GROWTH PROCESSING #2**

# %% [markdown]
# Proses FP-Growth frequent itemsets, simpan hasilnya sebagai dataframe data_freq2: <br> (parameter min_support=0.03)

# %%
freqItemsets2 = fpgrowth(data2transform, min_support=0.03, use_colnames = True)

# %%
data_freq2 = pd.DataFrame(freqItemsets2)

# %%
data_freq2.sort_values(by=['support'], ascending=False)
# Out:
#      support                                itemsets
# 2   0.531126                             (female_yn)
# 1   0.523150                            (medcond_yn)
# 0   0.468874                               (male_yn)
# 7   0.277490                 (female_yn, medcond_yn)
# 6   0.245660                   (male_yn, medcond_yn)
# 3   0.170959                               (hosp_yn)
# 10  0.143755                   (medcond_yn, hosp_yn)
# 9   0.091233                      (male_yn, hosp_yn)
# 8   0.079726                    (female_yn, hosp_yn)
# 12  0.077101          (male_yn, medcond_yn, hosp_yn)
# 11  0.066654        (female_yn, medcond_yn, hosp_yn)
# 4   0.059270                              (death_yn)
# 5   0.058190                                (icu_yn)
# 19  0.057308                       (icu_yn, hosp_yn)
# 14  0.055333                  (death_yn, medcond_yn)
# 21  0.051411                    (icu_yn, medcond_yn)
# 15  0.050934                     (death_yn, hosp_yn)
# 26  0.050831           (icu_yn, medcond_yn, hosp_yn)
# 18  0.048000         (death_yn, medcond_yn, hosp_yn)
# 20  0.035344                       (male_yn, icu_yn)
# 23  0.034883              (male_yn, icu_yn, hosp_yn)
# 13  0.033927                     (male_yn, death_yn)
# 22  0.032168                      (death_yn, icu_yn)
# 27  0.032072             (death_yn, icu_yn, hosp_yn)
# 16  0.031686         (male_yn, death_yn, medcond_yn)
# 24  0.031143           (male_yn, icu_yn, medcond_yn)
# 25  0.030828  (male_yn, icu_yn, medcond_yn, hosp_yn)
# 17  0.030321            (male_yn, death_yn, hosp_yn)
# 28  0.030028          (death_yn, icu_yn, medcond_yn)

# %% [markdown]
# Proses FP-Growth association rule, simpan hasilnya sebagai dataframe data_assoc2: <br> (parameter metric="lift"; min_threshold=1)

# %%
assocRules2 = association_rules(freqItemsets2, metric="lift", min_threshold=1)

# %%
data_assoc2 = pd.DataFrame(assocRules2)

# %%
data_assoc2.sort_values(by=['lift'], ascending=False)
# Out:
#               antecedents           consequents  antecedent support  \
# 84               (icu_yn)   (death_yn, hosp_yn)            0.058190
# 81    (death_yn, hosp_yn)              (icu_yn)            0.050934
# 89             (death_yn)  (icu_yn, medcond_yn)            0.059270
# 88   (icu_yn, medcond_yn)            (death_yn)            0.051411
# 83             (death_yn)     (icu_yn, hosp_yn)            0.059270
# ..                    ...                   ...                 ...
# 12  (medcond_yn, hosp_yn)             (male_yn)            0.143755
# 3               (hosp_yn)             (male_yn)            0.170959
# 2               (male_yn)             (hosp_yn)            0.468874
# 1            (medcond_yn)             (male_yn)            0.523150
# 0               (male_yn)          (medcond_yn)            0.468874
#
#     consequent support   support  confidence       lift  leverage  conviction
# 84            0.050934  0.032072    0.551158  10.821134  0.029108    2.114480
# 81            0.058190  0.032072    0.629681  10.821134  0.029108    2.543242
# 89            0.051411  0.030028    0.506624   9.854420  0.026981    1.922650
# 88            0.059270  0.030028    0.584075   9.854420  0.026981    2.261775
# 83            0.057308  0.032072    0.541112   9.442145  0.028675    2.054297
# ..                 ...       ...         ...        ...       ...         ...
# 12            0.468874  0.077101    0.536334   1.143878  0.009698    1.145494
# 3             0.468874  0.091233    0.533654   1.138161  0.011075    1.138910
# 2             0.170959  0.091233    0.194579   1.138161  0.011075    1.029326
# 1             0.468874  0.245660    0.469579   1.001504  0.000369    1.001330
# 0             0.523150  0.245660    0.523937   1.001504  0.000369    1.001653
#
# [92 rows x 9 columns]

# %%
data_assoc2.sort_values(by=['lift'], ascending=False).head(20)
# Out:
#                        antecedents                     consequents  \
# 84                        (icu_yn)             (death_yn, hosp_yn)
# 81             (death_yn, hosp_yn)                        (icu_yn)
# 89                      (death_yn)            (icu_yn, medcond_yn)
# 88            (icu_yn, medcond_yn)                      (death_yn)
# 83                      (death_yn)               (icu_yn, hosp_yn)
# 82               (icu_yn, hosp_yn)                      (death_yn)
# 46                      (death_yn)                        (icu_yn)
# 47                        (icu_yn)                      (death_yn)
# 90                        (icu_yn)          (death_yn, medcond_yn)
# 87          (death_yn, medcond_yn)                        (icu_yn)
# 62  (male_yn, medcond_yn, hosp_yn)                        (icu_yn)
# 71                        (icu_yn)  (male_yn, medcond_yn, hosp_yn)
# 67            (icu_yn, medcond_yn)              (male_yn, hosp_yn)
# 66              (male_yn, hosp_yn)            (icu_yn, medcond_yn)
# 49              (male_yn, hosp_yn)                        (icu_yn)
# 52                        (icu_yn)              (male_yn, hosp_yn)
# 77                        (icu_yn)           (medcond_yn, hosp_yn)
# 76           (medcond_yn, hosp_yn)                        (icu_yn)
# 69           (medcond_yn, hosp_yn)               (male_yn, icu_yn)
# 64               (male_yn, icu_yn)           (medcond_yn, hosp_yn)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 84            0.058190            0.050934  0.032072    0.551158  10.821134
# 81            0.050934            0.058190  0.032072    0.629681  10.821134
# 89            0.059270            0.051411  0.030028    0.506624   9.854420
# 88            0.051411            0.059270  0.030028    0.584075   9.854420
# 83            0.059270            0.057308  0.032072    0.541112   9.442145
# 82            0.057308            0.059270  0.032072    0.559639   9.442145
# 46            0.059270            0.058190  0.032168    0.542741   9.327060
# 47            0.058190            0.059270  0.032168    0.552818   9.327060
# 90            0.058190            0.055333  0.030028    0.516030   9.325852
# 87            0.055333            0.058190  0.030028    0.542671   9.325852
# 62            0.077101            0.058190  0.030828    0.399835   6.871196
# 71            0.058190            0.077101  0.030828    0.529775   6.871196
# 67            0.051411            0.091233  0.030828    0.599631   6.572536
# 66            0.091233            0.051411  0.030828    0.337900   6.572536
# 49            0.091233            0.058190  0.034883    0.382351   6.570742
# 52            0.058190            0.091233  0.034883    0.599468   6.570742
# 77            0.058190            0.143755  0.050831    0.873544   6.076615
# 76            0.143755            0.058190  0.050831    0.353598   6.076615
# 69            0.143755            0.035344  0.030828    0.214445   6.067380
# 64            0.035344            0.143755  0.030828    0.872216   6.067380
#
#     leverage  conviction
# 84  0.029108    2.114480
# 81  0.029108    2.543242
# 89  0.026981    1.922650
# 88  0.026981    2.261775
# 83  0.028675    2.054297
# 82  0.028675    2.136269
# 46  0.028720    2.059687
# 47  0.028720    2.103683
# 90  0.026808    1.951912
# 87  0.026808    2.059370
# 62  0.026341    1.569251
# 71  0.026341    1.962674
# 67  0.026137    2.269826
# 66  0.026137    1.432697
# 49  0.029574    1.524831
# 52  0.029574    2.268899
# 77  0.042466    6.771098
# 76  0.042466    1.457004
# 69  0.025747    1.227993
# 64  0.025747    6.700747

# %% [markdown]
# *****
# **INTERPRETASI SEDERHANA & KESIMPULAN EKSPERIMEN ROUND #2** <br><br>
#
#
# *   Hasil eksperimen #2 secara umum tidak jauh berbeda dengan eksperimen #1.
# *   Ternyata elemen "sex" tidak terlalu berpengaruh terhadap elemen-elemen lainnya. Hal ini dapat dilihat dari kemunculan elemen (male_yn) pada itemset 62, dengan confidence cukup rendah 0.399; dan sepuluh rules teratas dengan lift tertinggi tidak ada yang mengandung elemen (male_yn) maupun (female_yn).
# *   Dapat disimpulkan juga bahwa "sex" bukan faktor yang paling berhubungan dengan kematian. Hal ini terlihat dari tidak adanya asosiasi (male_yn) --> (death_yn) atau (female_yn) --> (death_yn) pada 20 rules dengan lift tertinggi.
# *   Wawasan asosiasi yang lebih komprehensif mungkin akan didapatkan dengan memasukkan features lainnya dari dataset tersebut, selain 5 features yang sudah dipilih.

# %% [markdown]
# Simpan dataframe hasil pemrosesan ke file csv:

# %%
data_freq.to_csv('/content/drive/MyDrive/DATASET1/Covid-19/Output_FPG/data_freq.csv')
data_assoc.to_csv('/content/drive/MyDrive/DATASET1/Covid-19/Output_FPG/data_assoc.csv')
data_freq2.to_csv('/content/drive/MyDrive/DATASET1/Covid-19/Output_FPG/data_freq2.csv')
data_assoc2.to_csv('/content/drive/MyDrive/DATASET1/Covid-19/Output_FPG/data_assoc2.csv')
